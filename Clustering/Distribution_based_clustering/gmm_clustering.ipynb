# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.mixture import GaussianMixture

# Generate a toy 2D dataset
X, y_true = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)

# %%
plt.scatter(X[:, 0], X[:, 1], s=40, cmap='viridis')

plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
# Out:
# C:\Users\avanindra Bose\AppData\Local\Temp\ipykernel_11828\92440043.py:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], s=40, cmap='viridis')

# %%
# Apply Gaussian Mixture Model clustering
gmm = GaussianMixture(n_components=4, random_state=0).fit(X)
labels = gmm.predict(X)

# %%
# Plotting the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, s=40, cmap='viridis')

# Optionally, plot the center of each cluster
centers = gmm.means_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

plt.title("GMM Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
